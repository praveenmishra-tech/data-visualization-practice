# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# Pie chart with plotly express

# %%
var=px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
print(var)
var.loc[var["pop"]<2.e6,"country"]="other contery"# Represent only large countries
#names = Pie Chart ke slices ke naam (labels)
#values = Har slice kitna bada hoga.
fig=px.pie(var,names="country",values="pop",title="praveen mishra")
fig.show()
# Out:
#                      country continent  year  lifeExp       pop     gdpPercap  \
# 23                   Albania    Europe  2007   76.423   3600523   5937.029526
# 83                   Austria    Europe  2007   79.829   8199783  36126.492700
# 119                  Belgium    Europe  2007   79.441  10392226  33692.605080
# 155   Bosnia and Herzegovina    Europe  2007   74.852   4552198   7446.298803
# 191                 Bulgaria    Europe  2007   73.005   7322858  10680.792820
# 383                  Croatia    Europe  2007   75.748   4493312  14619.222720
# 407           Czech Republic    Europe  2007   76.486  10228744  22833.308510
# 419                  Denmark    Europe  2007   78.332   5468120  35278.418740
# 527                  Finland    Europe  2007   79.313   5238460  33207.084400
# 539                   France    Europe  2007   80.657  61083916  30470.016700
# 575                  Germany    Europe  2007   79.406  82400996  32170.374420
# ...

# %%
# This dataframe has 244 lines, but 4 distinct values for `day`
df = px.data.tips()
fig = px.pie(df, values='tip', names='day')
fig.show()

# %% [markdown]
# Using an explicit mapping for discrete colors

# %%
var=px.data.tips()
fig=px.pie(var,names="day",values="tip",color_discrete_sequence=px.colors.sequential.BuPu)
fig.show()

# %%
# color_discrete_map
# Tum specific category → specific color decide karte ho.

# color_discrete_sequence
# Plotly khud colors ko order ke hisaab se categories me baant dega.

# %%
df = px.data.tips()
fig = px.pie(df, values='tip', names='day', color='day',
             color_discrete_map={'Thur':'lightcyan',
                                 'Fri':'cyan',
                                 'Sat':'royalblue',
                                 'Sun':'darkblue'})
fig.show()

# %% [markdown]
# Donut Chart

# %%
import plotly.graph_objects as go

labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.show()

# %% [markdown]
# Pulling sectors out from the center

# %% [markdown]
# # explode = (0, 0.2, 0)   # B wala slice bahar niklega
# # Plotly me pull use hota hai.

# %%
labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

# pull is given as a fraction of the pie radius
fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0, 0, 0.2, 0])])
fig.show()

# %% [markdown]
# A Sunburst Plot is a circular chart used to visualize hierarchical (parent-child) data. The root node is placed at the center, and each level of the hierarchy is displayed as concentric rings moving outward. In Plotly Express, hierarchy is created using the names and parents parameters, while values can be used to control the size of each segment.

# %%
fig=dict(
    character=["Eve", "Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"],
    parent=["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve"],
    values=[10, 14, 12, 10, 2, 6, 6, 4, 4]

)
var=px.sunburst(fig,names='character',parents='parent',values='values',)
var.show()

# %%
df = px.data.tips()
print(df)
fig = px.sunburst(df, path=['day', 'time', 'sex'], values='total_bill')
fig.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(df, path=['continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.show()
